# %% [markdown]
# # Session 2: Probability - Practice Exercises
#
# ## 🎯 Goal
# 확률 계산과 시뮬레이션을 내 손으로 직접 구현해봅니다.
#
# ---

# %% [markdown]
# ## 🧩 Part 1. Concept Quiz
#
# 1. 두 사건 A와 B가 '독립(Independent)'일 때 성립하는 공식은?
#    - A) $P(A \cap B) = P(A) + P(B)$
#    - B) $P(A \cap B) = P(A)P(B)$
#    - C) $P(A | B) = P(B)$
#
# 2. 베이즈 정리 $P(A|B) = \frac{P(B|A)P(A)}{P(B)}$ 에서 $P(A)$가 의미하는 것은?
#    - A) 우도 (Likelihood)
#    - B) 사후 확률 (Posterior)
#    - C) 사전 확률 (Prior)
#
# 3. 자연어 텍스트의 단어 빈도 분포가 따르는 법칙은?
#    - A) 정규 분포 (Gaussian)
#    - B) 지프의 법칙 (Zipf's Law)
#    - C) 균등 분포 (Uniform)

# %% [markdown]
# ---
# ## ⌨️ Part 2. Coding Drill
#
# ### Drill 1: 주사위 시뮬레이터
# 주사위 2개를 10,000번 던졌을 때, 두 눈의 합이 7이 나올 확률을 구하는 시뮬레이션 코드를 작성하세요.
# (이론적 확률: 6/36 = 1/6 $\approx$ 0.166...)

# %%
import random

trials = 10000
count_seven = 0

for _ in range(trials):
    dice1 = random.randint(1, 6)
    dice2 = random.randint(1, 6)
    
    # TODO: 합이 7이면 카운트 증가
    
print(f"Prob: {count_seven / trials}")

# %% [markdown]
# ---
# ## 🔥 Part 3. Challenge
#
# ### Challenge: 스팸 필터 (Naive Bayes 맛보기)
# 특정 단어("Free")가 등장했을 때, 그 메일이 스팸일 확률 $P(\text{Spam}|\text{Free})$을 구하세요.
#
# **주어진 정보**:
# - 전체 메일 중 스팸 비율 $P(\text{Spam}) = 0.3$
# - 스팸 메일 중 "Free"가 있을 확률 $P(\text{Free}|\text{Spam}) = 0.8$
# - 일반 메일 중 "Free"가 있을 확률 $P(\text{Free}|\text{Ham}) = 0.1$

# %%
# 힌트: 분모 P(Free)를 먼저 구해야 함
# P(Free) = P(Free|Spam)P(Spam) + P(Free|Ham)P(Ham)

p_spam = 0.3
p_ham = 0.7
p_free_given_spam = 0.8
p_free_given_ham = 0.1

# TODO: P(Spam|Free) 계산

# %% [markdown]
# ---
#
# ## 💡 Solutions
#
# ### Quiz Answers
# 1. B
# 2. C (Prior)
# 3. B (Zipf)
#
# ### Drill Code
# ```python
# if dice1 + dice2 == 7:
#     count_seven += 1
# ```
