# %% [markdown]
# # Session 4: Vectors & Evaluation - Practice Exercises
#
# ## 🎯 Goal
# 벡터 연산으로 유사도를 구하고, 모델의 성능을 평가하는 지표를 계산해봅니다.
#
# ---

# %% [markdown]
# ## 🧩 Part 1. Concept Quiz
#
# 1. 코사인 유사도(Cosine Similarity)는 두 벡터의 무엇을 비교하는가?
#    - A) 크기 (Magnitude)
#    - B) 방향 (Direction)
#    - C) 거리 (Distance)
#
# 2. 정밀도(Precision)와 재현율(Recall)의 조화 평균을 무엇이라 하는가?
#    - A) Accuracy
#    - B) F1-score
#    - C) ROC-AUC
#
# 3. 차원의 저주(Curse of Dimensionality)에 대한 설명으로 맞는 것은?
#    - A) 차원이 높을수록 데이터 간의 구분이 쉬워진다.
#    - B) 차원이 높을수록 모든 데이터 간의 거리가 멀어지고 비슷해진다.
#    - C) 차원이 높을수록 계산량이 줄어든다.

# %% [markdown]
# ---
# ## ⌨️ Part 2. Coding Drill
#
# ### Drill 1: Precision & Recall 계산
# TP, FP, FN 값이 주어졌을 때, Precision과 Recall을 반환하는 함수를 작성하세요.
# $$ P = \frac{TP}{TP + FP}, \quad R = \frac{TP}{TP + FN} $$

# %%
def calc_metrics(tp, fp, fn):
    precision = 0
    recall = 0
    # TODO
    return precision, recall

print(calc_metrics(tp=10, fp=2, fn=5))

# %% [markdown]
# ---
# ## 🔥 Part 3. Challenge
#
# ### Challenge: 가장 유사한 문서 찾기
# 주어진 쿼리 벡터와 가장 유사도(내적 혹은 코사인 유사도)가 높은 문서 벡터를 찾으세요.

# %%
import numpy as np

query = np.array([1, 1])
docs = [
    np.array([1, 0]),
    np.array([0, 1]),
    np.array([0.9, 0.9]),
    np.array([-1, -1])
]

def find_best_match(query, docs):
    best_score = -1
    best_doc_idx = -1
    
    # TODO: 반복문으로 코사인 유사도 비교

    return best_doc_idx

print(f"Best Doc Index: {find_best_match(query, docs)}")

# %% [markdown]
# ---
#
# ## 💡 Solutions
#
# ### Quiz Answers
# 1. B
# 2. B
# 3. B
#
# ### Drill Code
# ```python
# def calc_metrics(tp, fp, fn):
#     precision = tp / (tp + fp)
#     recall = tp / (tp + fn)
#     return precision, recall
# ```
