# %% [markdown]
# # Session 0: Math Basics - Practice Exercises
#
# ## 🎯 Goal
# 이론에서 배운 수식($\sum, \prod$)과 미분, 내적을 직접 코드로 구현하며 내 것으로 만듭니다.
#
# ---

# %% [markdown]
# ## 🧩 Part 1. Concept Quiz
#
# 1. 수학 기호 $\sum_{i=1}^{n} x_i$를 파이썬의 `for` 문으로 구현할 때, 누적 변수(`total`)의 초기값은 얼마여야 합니까?
#    - A) 1
#    - B) 0
#    - C) x[0]
#
# 2. 미분을 컴퓨터로 근사할 때 사용하는 '수치 미분' 공식은 무엇입니까?
#    - A) $(f(x+h) + f(x)) / h$
#    - B) $(f(x+h) - f(x)) / h$
#    - C) $f(x) * h$
#
# 3. 두 벡터의 내적(Dot Product)이 0이라면, 두 벡터의 관계는?
#    - A) 서로 평행하다 (같은 방향)
#    - B) 서로 반대 방향이다
#    - C) 서로 직교한다 (90도)

# %% [markdown]
# ---
# ## ⌨️ Part 2. Coding Drill
#
# ### Drill 1: Sigma & Pi 구현하기
# 리스트의 모든 요소를 제곱해서 더하는 함수 `sum_of_squares`와,
# 모든 요소를 제곱해서 곱하는 함수 `prod_of_squares`를 `for` 리문으로 작성하세요.

# %%
data = [1, 2, 3, 4, 5]

def sum_of_squares(arr):
    total = 0
    # TODO: for 문으로 구현
    return total

def prod_of_squares(arr):
    total = 1
    # TODO: for 문으로 구현
    return total

print(f"Sum Result: {sum_of_squares(data)} (Expected: 55)")
print(f"Prod Result: {prod_of_squares(data)} (Expected: 14400)")

# %% [markdown]
# ---
# ## 🔥 Part 3. Challenge
#
# ### Challenge: 최적의 h를 찾아라
# 수치 미분에서 `h` 값이 너무 크면 오차가 크고, 너무 작으면 부동소수점 에러가 납니다.
# $f(x) = x^3$ 함수에 대해 $x=2$에서의 미분값(정답: $3x^2 = 12$)을 구할 때,
# 오차가 가장 작은 `h` 값을 실험을 통해 찾아보세요.
#
# **후보군**: `[1e-1, 1e-2, ..., 1e-15, 1e-16]`

# %%
# TODO: 코드를 작성하세요
def func(x):
    return x**3

actual_slope = 12.0
h_candidates = [10**(-i) for i in range(1, 17)]

# Loop 돌면서 오차 출력

# %% [markdown]
# ---
#
# ## 💡 Solutions (정답 미리보기 금지!)
#
# ### Quiz Answers
# 1. B (덧셈의 항등원은 0)
# 2. B (변화량 / h)
# 3. C (내적이 0이면 직교)
#
# ### Drill Code
# ```python
# def sum_of_squares(arr):
#     total = 0
#     for x in arr:
#         total += x**2
#     return total
#
# def prod_of_squares(arr):
#     total = 1
#     for x in arr:
#         total *= x**2
#     return total
# ```
