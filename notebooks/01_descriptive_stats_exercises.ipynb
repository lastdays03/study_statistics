# %% [markdown]
# # Session 1: Descriptive Stats - Practice Exercises
#
# ## 🎯 Goal
# 평균, 분산, 표준편차를 직접 계산하고, 이상치를 처리하는 방법을 연습합니다.
#
# ---

# %% [markdown]
# ## 🧩 Part 1. Concept Quiz
#
# 1. 표본 분산을 구할 때 자유도 보정을 위해 분모에 사용하는 값은? ($n$은 데이터 개수)
#    - A) $n$
#    - B) $n-1$
#    - C) $n+1$
#
# 2. 데이터가 한쪽으로 매우 치우쳐져(Skewed) 있을 때 가장 적절한 대푯값은?
#    - A) 평균 (Mean)
#    - B) 중앙값 (Median)
#    - C) 최빈값 (Mode)
#
# 3. 표준편차($\sigma$)는 분산($\sigma^2$)에 무엇을 한 값인가?
#    - A) 제곱
#    - B) 로그
#    - C) 제곱근 (Root)

# %% [markdown]
# ---
# ## ⌨️ Part 2. Coding Drill
#
# ### Drill 1: 이상치 탐지기 (z-score)
# 데이터 포인트가 평균에서 표준편차의 몇 배만큼 떨어져 있는지(z-score) 계산하는 함수를 작성하세요.
# $$ z = \frac{x - \mu}{\sigma} $$

# %%
import numpy as np

data = [10, 12, 12, 13, 12, 11, 14, 100] # 100은 이상치

def calculate_z_scores(data):
    mean = np.mean(data)
    std = np.std(data)
    z_scores = []
    
    # TODO: z-score 계산
    
    return z_scores

print(calculate_z_scores(data))

# %% [markdown]
# ---
# ## 🔥 Part 3. Challenge
#
# ### Challenge: 이상치 제거 후 통계량 변화
# 위 데이터에서 `z-score`가 **2.0 이상**인 데이터를 제거(Filtering)한 후,
# 제거 전/후의 **평균**과 **분산**이 얼마나 변했는지 계산하여 출력하세요.

# %%
# TODO: 코드를 작성하세요

# %% [markdown]
# ---
#
# ## 💡 Solutions
#
# ### Quiz Answers
# 1. B (n-1)
# 2. B (중앙값)
# 3. C (제곱근)
#
# ### Drill Code
# ```python
# def calculate_z_scores(data):
#     mean = np.mean(data)
#     std = np.std(data)
#     return [(x - mean) / std for x in data]
# ```
