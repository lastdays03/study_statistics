# %% [markdown]
# # Session 3: Correlation & Regression - Practice Exercises
#
# ## 🎯 Goal
# 데이터의 관계를 파악하고, 예측 모델을 직접 학습시켜 봅니다.
#
# ---

# %% [markdown]
# ## 🧩 Part 1. Concept Quiz
#
# 1. 상관계수(Correlation Coefficient) $r$의 범위로 올바른 것은?
#    - A) $0 \le r \le 1$
#    - B) $-1 \le r \le 1$
#    - C) $-\infty \le r \le \infty$
#
# 2. 상관관계가 0이면 두 변수는 아무런 관계가 없는 것인가?
#    - A) 그렇다.
#    - B) 아니다. (선형 관계만 없을 뿐, 2차 함수 등 비선형 관계일 수 있다)
#
# 3. 선형 회귀에서 손실 함수(MSE)를 최소화하기 위해 파라미터를 업데이트하는 방법은?
#    - A) 경사하강법 (Gradient Descent)
#    - B) 몬테카를로 (Monte Carlo)
#    - C) 유클리드 거리 (Euclidean Distance)

# %% [markdown]
# ---
# ## ⌨️ Part 2. Coding Drill
#
# ### Drill 1: MSE (Mean Squared Error) 계산기
# 실제값 `y_true`와 예측값 `y_pred` 리스트가 주어졌을 때, MSE를 구하는 함수를 작성하세요.
# $$ MSE = \frac{1}{n} \sum (y_{true} - y_{pred})^2 $$

# %%
import numpy as np

y_true = np.array([1, 2, 3])
y_pred = np.array([1.1, 1.9, 3.2])

def calculate_mse(true, pred):
    # TODO: MSE 계산
    return 0.0

print(f"MSE: {calculate_mse(y_true, y_pred)}")

# %% [markdown]
# ---
# ## 🔥 Part 3. Challenge
#
# ### Challenge: 직접 만든 데이터 회귀하기
# $y = 5x + 10$ 관계를 가지는 데이터셋(약간의 노이즈 포함)을 만들고,
# Scikit-learn의 `LinearRegression` 모델을 사용해 기울기(5)와 절편(10)을 맞추는지 확인해보세요.

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# 1. 데이터 생성 (X: 0~10 사이 난수 100개)
X = np.random.rand(100, 1) * 10
y = 5 * X + 10 + np.random.randn(100, 1) # 노이즈 추가

# 2. 모델 학습
# TODO

# 3. 결과 출력 (coef_, intercept_)
# TODO

# %% [markdown]
# ---
#
# ## 💡 Solutions
#
# ### Quiz Answers
# 1. B
# 2. B (단순히 선형 상관관계가 없다는 뜻)
# 3. A
#
# ### Drill Code
# ```python
# def calculate_mse(true, pred):
#     return np.mean((true - pred)**2)
# ```
